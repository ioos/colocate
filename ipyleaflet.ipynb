# %%
import ui
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-543dba3e0d27> in <module>
# ----> 1 import ui
#
# ModuleNotFoundError: No module named 'ui'

# %%
ui.m

# %%
ui.dates

# %%
ui.button

# %%
ui.kw
